# %% [markdown]
# Q4001 Thermodynamics of Materials <br>
# <b>Class Activity 1</b> <br>
# Osamu Katagiri - A01212611@itesm.mx - CEM <br>

# %%
#******************************************************************************#
# Futures
# %matplotlib inline
# from __future__ import unicode_literals
# from __future__ import print_function

# Generic/Built-in
import datetime
import argparse

# Other Libs
from IPython.display import display, Image
#
from sympy import *
#
import matplotlib.pyplot as plt
plt.rc('xtick', labelsize=14)     
plt.rc('ytick', labelsize=14)
#
import numpy as np
np.seterr(divide='ignore', invalid='ignore')

# Owned
# from nostalgia_util import log_utils
# from nostalgia_util import settings_util
__authors__   = ["Osamu Katagiri - A01212611@itesm.mx"]
__copyright__ = "None"
__credits__   = ["Marcelo Videa - mvidea@itesm.mx"]
__license__   = "None"
__status__    = "Under Work"
#******************************************************************************#

# %% [markdown]
# ## Exercise 1
# ___

# %%
# Function to compute the coefficient of linear expansion of rubber at constant tensile stress and volume takes
def G_(H, S, T):
    return H - T*S;

# Draw the plot's workspace
scale = 6;
plt.subplots(figsize=(3*scale, 2*scale));

# Define constants
P = 1.01; #Kg/m3
Cp = 1965; #J/Kg K
T0 = 298.15; #K
k = np.linspace(0.0, 0.00012, 1000);
L0 = 1; #length in the absence of applied stress
Clv = 0.178; #J/K mol

Tmin = -7500 - 1000
Tmax = 5552.035 + 1000
T = np.linspace(Tmin, Tmax, 1000);

# Plot
H = 116.926
S = 0.174847
G1 = G_(H, S, T)
plt.plot(T, G1, '-', linewidth=3, label=r'$ {Mg C O_3}_{(s)} \rightarrow {Mg O}_{(s)} + {C O_2}_{(g)} $');

H = 601.241
S = 0.108292
G2 = G_(H, S, T)
plt.plot(T, G2, '-', linewidth=3, label=r'$ {Mg O}_{(s)} \rightarrow {Mg}_{(g)} + \frac{1}{2}{O_2}_{(g)} $');

Tzeros = np.linspace(0, 0, 1000);
plt.plot(T, Tzeros, ':', linewidth=3);

#T298 = np.linspace(298, 298, 1000);
#y = np.linspace(min(G1), max(G1), 1000);
#plt.plot(Tzeros, y, ':', linewidth=3);

# Display plots
plt.xlabel(r'$T$' + '    ' + r'$[K]$', fontsize=24);
plt.ylabel(r'${{\Delta G}^\theta}_{sys}$' + '    ' + r'$[kJ mol^{-1}]$', fontsize=24);
plt.title('Figure 1.' + r'$ {Mg C O_3}_{(s)} $', size=24);
plt.legend(prop={'size': 18});
display(plt);
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\oskat\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>
