# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.discrete.discrete_model import Logit
from statsmodels.tools.tools import add_constant

# %%
spam_df = pd.read_csv('spam.csv')

# %%
spam_df.head()
# Out:
#    spam  make  address   all   3d   our  over  remove  internet  order  ...  \
# 0  True  0.00     0.64  0.64  0.0  0.32  0.00    0.00      0.00   0.00  ...
# 1  True  0.21     0.28  0.50  0.0  0.14  0.28    0.21      0.07   0.00  ...
# 2  True  0.06     0.00  0.71  0.0  1.23  0.19    0.19      0.12   0.64  ...
# 3  True  0.00     0.00  0.00  0.0  0.63  0.00    0.31      0.63   0.31  ...
# 4  True  0.00     0.00  0.00  0.0  0.63  0.00    0.31      0.63   0.31  ...
#
#    conference   ch;    ch(  ch[    ch!    ch$    ch#  crl.ave  crl.long  \
# 0         0.0  0.00  0.000  0.0  0.778  0.000  0.000    3.756        61
# 1         0.0  0.00  0.132  0.0  0.372  0.180  0.048    5.114       101
# 2         0.0  0.01  0.143  0.0  0.276  0.184  0.010    9.821       485
# 3         0.0  0.00  0.137  0.0  0.137  0.000  0.000    3.537        40
# 4         0.0  0.00  0.135  0.0  0.135  0.000  0.000    3.537        40
#
#    crl.tot
# 0      278
# 1     1028
# 2     2259
# 3      191
# 4      191
# ...

# %%
logit_mod = Logit(spam_df['spam'], 
                  add_constant(spam_df.drop('spam',1))).fit()
logit_mod.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# Optimization terminated successfully.
#          Current function value: 0.197323
#          Iterations 15
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   spam   No. Observations:                 4601
# Model:                          Logit   Df Residuals:                     4543
# Method:                           MLE   Df Model:                           57
# Date:                Tue, 15 Oct 2019   Pseudo R-squ.:                  0.7057
# Time:                        09:17:46   Log-Likelihood:                -907.88
# converged:                       True   LL-Null:                       -3085.1
# ...

# %%
logit_mod = Logit(spam_df['spam'], 
                  add_constant(spam_df.drop(['spam', 'all', '3d', 'order', 'mail', 'email',
                                             'hpl', '1999', 'pm', 'conference', 'ch;'],1))).fit_regularized(alpha=15)
logit_mod.summary()
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.30016023161427485
#             Iterations: 165
#             Function evaluations: 176
#             Gradient evaluations: 165
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   spam   No. Observations:                 4601
# Model:                          Logit   Df Residuals:                     4574
# Method:                           MLE   Df Model:                           26
# Date:                Tue, 15 Oct 2019   Pseudo R-squ.:                  0.6429
# Time:                        09:24:44   Log-Likelihood:                -1101.8
# converged:                       True   LL-Null:                       -3085.1
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...
